# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Incidents_Responded_to_by_Fire_Companies.csv', delimiter=',',low_memory=False)

# %%
incidents = df['INCIDENT_TYPE_DESC'].unique().tolist()
count_list = df['INCIDENT_TYPE_DESC'].value_counts().tolist()
#type(count_list)

# %%
count_list[0]/sum(count_list)
# Out:
# 0.3614828304238471

# %%
incident_111 = df['INCIDENT_TYPE_DESC'] == '111 - Building fire'
incident_651 = df['INCIDENT_TYPE_DESC'] == '651 - Smoke scare, odor of smoke'
df_111 = df[first_incident]
#df_111.head()
df_651 = df[second_incident]

# %%
a1 = pd.to_numeric(df_111['UNITS_ONSCENE'])
a2 = pd.to_numeric(df_651['UNITS_ONSCENE'])
#a2.head()
print(a1.mean() / a2.mean())
# Out:
# 2.7597595139775324

# %%
#staten = df['BOROUGH_DESC'] == '3-Staten Island'
#manhattan = df['BOROUGH_DESC'] == '1-Manhattan'
#df_staten = df[staten]
#df_manhattan = df[manhattan]

# %%
false_call = df['INCIDENT_TYPE_DESC'] == '710 - Malicious, mischievous false call, other'
df_false = df[false_call]
#df_false.head()

# %%
#len(df)

# %%
s_f = df_false['BOROUGH_DESC'] == '3 - Staten Island'
m_f = df_false['BOROUGH_DESC'] == '1 - Manhattan'
s_false = df_false[s_f]
m_false = df_false[m_f]

# %%
rate_s = len(s_false) / len(df)
rate_m = len(m_false) / len(df)
print(rate_s/rate_m)
# Out:
# 0.327892234548336

# %%
arrival_time_111 = pd.to_datetime(df_111['ARRIVAL_DATE_TIME'], infer_datetime_format=True).dropna()
incident_time_111 = pd.to_datetime(df_111['INCIDENT_DATE_TIME'], infer_datetime_format=True).dropna()

# %%
import datetime as dt
a_i_diff = (arrival_time_111-incident_time_111).dt.total_seconds()/60
print(dq.quantile(0.75))

# %%
df['INCIDENT_DATE_TIME'] = pd.to_datetime(df['INCIDENT_DATE_TIME'], infer_datetime_format=True)

# %%
df['hour'] = df['INCIDENT_DATE_TIME'].dt.hour

# %%
hour_list = df['hour'].value_counts()
#print(hour_list)

# %%
cooking_portion=[]
for h in range(24):
    filtered_df = df[(df['INCIDENT_TYPE_DESC'] == '113 - Cooking fire, confined to container') & (df['hour'] == h)]
    #condition = df['INCIDENT_TYPE_DESC'] == '113 - Cooking fire, confined to container' and df['hour'] == hour
    portion = len(filtered_df)/float(hour_list[h])
    cooking_portion.append(portion)
#print(cooking_portion)

# %%
print(cooking_portion.index(max(cooking_portion)))

# %%
zip_df = pd.read_csv('2010+Census+Population+By+Zipcode+(ZCTA).csv', delimiter=',')
zip_df.head()
# Out:
#    Zip Code ZCTA  2010 Census Population
# 0           1001                   16769
# 1           1002                   29049
# 2           1003                   10372
# 3           1005                    5079
# 4           1007                   14649

# %%
def test_apply(x):
    try:
        return int(x)
    except ValueError:
        return None
clean_df = df['ZIP_CODE'].apply(test_apply)
df['ZIP_CODE'] = clean_df

# %%
pd.merge(df, zip_df, left_on='ZIP_CODE', right_on='Zip Code ZCTA', how='outer')
# Out:
#          IM_INCIDENT_KEY FIRE_BOX  \
# 0             55672688.0     2147
# 1             55673482.0     2147
# 2             55673584.0     2172
# 3             55673931.0     2115
# 4             55673971.0     2163
# 5             55674190.0     2186
# 6             55674283.0     2162
# 7             55675078.0     2141
# 8             55675235.0     2141
# 9             55675877.0     2176
# 10            55675904.0     2129
# 11            55675968.0     2146
# 12            55676095.0     2113
# 13            55676255.0     2147
# 14            55677212.0     2127
# 15            55677758.0     2134
# 16            55678277.0     2229
# 17            55678439.0     2156
# 18            55679082.0     2173
# 19            55679116.0     2149
# 20            55679252.0     2119
# 21            55679470.0     2139
# 22            55679793.0     2145
# 23            55679964.0     2194
# 24            55680141.0     2156
# 25            55680255.0     2135
# ...

# %%
len(df)
# Out:
# 2277779

# %%
zip_df[zip_df['Zip Code ZCTA'] == 1001]['2010 Census Population'].values[0]
#pd.to_numeric(df['ZIP_CODE'], errors='ignore', dtype='int64')
clean_df['ZIP_CODE'] = clean_df['ZIP_CODE'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index._bin_search()
#
# TypeError: '<' not supported between instances of 'numpy.ndarray' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ...

# %%
pd.merge(df, zip_df, left_on='ZIP_CODE', right_on='Zip Code ZCTA', how='outer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-249-a25b39cef022> in <module>
# ----> 1 pd.merge(df, zip_df, left_on='ZIP_CODE', right_on='Zip Code ZCTA', how='outer')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
codes = zip_df['Zip Code ZCTA'].tolist()
for code in codes:
    if df['ZIP_CODE'] == code:
        df['population'] = zip_df[zip_df['Zip Code ZCTA'] == code]['2010 Census Population'].values[0]
    print(pop)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-246-f2f015348779> in <module>
#       1 codes = zip_df['Zip Code ZCTA'].tolist()
#       2 for code in codes:
# ----> 3     if df['ZIP_CODE'] == code:
#       4         df['population'] = zip_df[zip_df['Zip Code ZCTA'] == code]['2010 Census Population'].values[0]
#       5     print(pop)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
